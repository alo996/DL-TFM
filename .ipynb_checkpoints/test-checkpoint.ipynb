# %% [markdown]
# # Test

# %% [markdown]
# ### Imports

# %%
from tracNet import TracNet
from data_preparation import matFiles_to_npArray, reshape
from training_and_evaluation import test, predictTrac
from data_visualization import plotCell

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch

from IPython.display import Image
from shapely.geometry import Point, Polygon
from scipy.io import loadmat, savemat
from scipy.interpolate import interp2d

# %% [markdown]
# Set seeds for reproducability.

# %%
random_seed = 2
np.random.seed(random_seed)
torch.manual_seed(random_seed)

# %% [markdown]
# The test sets are of small size, so no CUDA support is needed.

# %%
device = torch.device('cpu')

# %% [markdown]
# Load all relevant models.

# %%
model_SGD = TracNet(n_channels=1).double().to(device)
# Martinsried
model_SGD.load_state_dict(torch.load('/home/alexrichard/LRZ Sync+Share/ML in Physics/Models/TracNet104-2022-Jun-22 18:43:08_best val_rmse_is_2.601_SGD.pth'), strict=False)
# Mac
# model_SGD.load_state_dict(torch.load('/Users/alex/LRZ Sync+Share/ML in Physics/Models/TracNet104-2022-Jun-22 18:43:08_best val_rmse_is_2.601_SGD.pth'), strict=False)
# Out:
# <All keys matched successfully>

# %%
model_ADAM = TracNet(n_channels=1).double().to(device)
# Martinsried
model_ADAM.load_state_dict(torch.load('/home/alexrichard/LRZ Sync+Share/ML in Physics/Models/TracNet104-2022-Jun-17 13:07:58_best val_rmse_is_1.537.pth'), strict=False)
# Mac
# model_ADAM.load_state_dict(torch.load('/Users/alex/LRZ Sync+Share/ML in Physics/Models/TracNet104-2022-Jun-22 18:43:08_best val_rmse_is_2.601_SGD.pth'), strict=False)
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### 1. Artificial test data from authors

# %% [markdown]
# Prepare test data.

# %%
# Martinsried
test_dspl_path = '/home/alexrichard/LRZ Sync+Share/ML in Physics/Repos/DL-TFM-main/test/generic/testData104/dspl'
test_trac_path = '/home/alexrichard/LRZ Sync+Share/ML in Physics/Repos/DL-TFM-main/test/generic/testData104/trac'
# Mac
# test_dspl_path = '/Users/alex/LRZ Sync+Share/ML in Physics/Repos/DL-TFM-main/test/generic/testData104/dspl'
# test_trac_path = '/Users/alex/LRZ Sync+Share/ML in Physics/Repos/DL-TFM-main/test/generic/testData104/trac'

# %%
X_test = matFiles_to_npArray(test_dspl_path) # each dict has keys ['brdx', 'brdy', 'dspl', 'name']
y_test = matFiles_to_npArray(test_trac_path) # each dict has keys ['brdx', 'brdy', 'trac', 'name']

# %% [markdown]
# Calculate loss for both models.

# %%
_, errors_SGD = test(X_test, y_test, model_SGD, 10670, plot=False)
_, errors_ADAM = test(X_test, y_test, model_ADAM, 10670, plot=False)
# Out:
# /home/alexrichard/.local/lib/python3.8/site-packages/torch/nn/modules/conv.py:587: UserWarning: Using padding='same' with even kernel lengths and odd dilation may require a zero-padded copy of the input be created (Triggered internally at  ../aten/src/ATen/native/Convolution.cpp:744.)
#   return F.conv3d(

# %% [markdown]
# Compare the losses.

# %%
pd.set_option('display.width', 1000)
pd.set_option('display.colheader_justify', 'center')
pd.set_option('display.precision', 3)

# %%
df = pd.read_csv("/home/alexrichard/PycharmProjects/ml_in_biophysics/outputs/TError.csv", usecols= ["File ID", "104"])
df = df.assign(error_Matlab_SGD=[tensor.item() for tensor in dict(sorted(errors_SGD.items())).values()])
df = df.assign(error_Matlab_ADAM=[tensor.item() for tensor in dict(sorted(errors_ADAM.items())).values()])
df = df.rename(columns = {"104":"TracNet_SGD_Matlab error", "error_Matlab_SGD":"TracNet_SGD_Python error", "error_Matlab_ADAM":"TracNet_ADAM_Python error"}).round(decimals=4)
df = df.append({'File ID':'', 'TracNet_SGD_Matlab error': f"avg: {round(df['TracNet_SGD_Matlab error'].mean(), ndigits=4)}", 'TracNet_SGD_Python error': f"avg: {round(df['TracNet_SGD_Python error'].mean(), ndigits=4)}", 'TracNet_ADAM_Python error': f"avg: {round(df['TracNet_ADAM_Python error'].mean(), ndigits=4)}"}, ignore_index=True)
df.style.set_properties(**{'text-align': 'center', 'font-size': '11pt'})
# Out:
# <style type="text/css">
# #T_872f5_row0_col0, #T_872f5_row0_col1, #T_872f5_row0_col2, #T_872f5_row0_col3, #T_872f5_row1_col0, #T_872f5_row1_col1, #T_872f5_row1_col2, #T_872f5_row1_col3, #T_872f5_row2_col0, #T_872f5_row2_col1, #T_872f5_row2_col2, #T_872f5_row2_col3, #T_872f5_row3_col0, #T_872f5_row3_col1, #T_872f5_row3_col2, #T_872f5_row3_col3, #T_872f5_row4_col0, #T_872f5_row4_col1, #T_872f5_row4_col2, #T_872f5_row4_col3, #T_872f5_row5_col0, #T_872f5_row5_col1, #T_872f5_row5_col2, #T_872f5_row5_col3, #T_872f5_row6_col0, #T_872f5_row6_col1, #T_872f5_row6_col2, #T_872f5_row6_col3, #T_872f5_row7_col0, #T_872f5_row7_col1, #T_872f5_row7_col2, #T_872f5_row7_col3, #T_872f5_row8_col0, #T_872f5_row8_col1, #T_872f5_row8_col2, #T_872f5_row8_col3, #T_872f5_row9_col0, #T_872f5_row9_col1, #T_872f5_row9_col2, #T_872f5_row9_col3, #T_872f5_row10_col0, #T_872f5_row10_col1, #T_872f5_row10_col2, #T_872f5_row10_col3, #T_872f5_row11_col0, #T_872f5_row11_col1, #T_872f5_row11_col2, #T_872f5_row11_col3, #T_872f5_row12_col0, #T_872f5_row12_col1, #T_872f5_row12_col2, #T_872f5_row12_col3, #T_872f5_row13_col0, #T_872f5_row13_col1, #T_872f5_row13_col2, #T_872f5_row13_col3, #T_872f5_row14_col0, #T_872f5_row14_col1, #T_872f5_row14_col2, #T_872f5_row14_col3, #T_872f5_row15_col0, #T_872f5_row15_col1, #T_872f5_row15_col2, #T_872f5_row15_col3, #T_872f5_row16_col0, #T_872f5_row16_col1, #T_872f5_row16_col2, #T_872f5_row16_col3, #T_872f5_row17_col0, #T_872f5_row17_col1, #T_872f5_row17_col2, #T_872f5_row17_col3 {
#   text-align: center;
#   font-size: 11pt;
# }
# </style>
# <table id="T_872f5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >File ID</th>
#       <th class="col_heading level0 col1" >TracNet_SGD_Matlab error</th>
#       <th class="col_heading level0 col2" >TracNet_SGD_Python error</th>
#       <th class="col_heading level0 col3" >TracNet_ADAM_Python error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_872f5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_872f5_row0_col0" class="data row0 col0" >#0018</td>
#       <td id="T_872f5_row0_col1" class="data row0 col1" >0.114</td>
#       <td id="T_872f5_row0_col2" class="data row0 col2" >0.187</td>
#       <td id="T_872f5_row0_col3" class="data row0 col3" >0.113</td>
#     </tr>
#     <tr>
#       <th id="T_872f5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_872f5_row1_col0" class="data row1 col0" >#0022</td>
#       <td id="T_872f5_row1_col1" class="data row1 col1" >0.123</td>
#       <td id="T_872f5_row1_col2" class="data row1 col2" >0.265</td>
#       <td id="T_872f5_row1_col3" class="data row1 col3" >0.155</td>
#     </tr>
#     <tr>
#       <th id="T_872f5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_872f5_row2_col0" class="data row2 col0" >#0023</td>
#       <td id="T_872f5_row2_col1" class="data row2 col1" >0.102</td>
#       <td id="T_872f5_row2_col2" class="data row2 col2" >0.192</td>
#       <td id="T_872f5_row2_col3" class="data row2 col3" >0.107</td>
#     </tr>
#     <tr>
#       <th id="T_872f5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_872f5_row3_col0" class="data row3 col0" >#0024</td>
#       <td id="T_872f5_row3_col1" class="data row3 col1" >0.115</td>
#       <td id="T_872f5_row3_col2" class="data row3 col2" >0.254</td>
#       <td id="T_872f5_row3_col3" class="data row3 col3" >0.110</td>
#     </tr>
#     <tr>
#       <th id="T_872f5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_872f5_row4_col0" class="data row4 col0" >#0025</td>
#       <td id="T_872f5_row4_col1" class="data row4 col1" >0.114</td>
#       <td id="T_872f5_row4_col2" class="data row4 col2" >0.205</td>
#       <td id="T_872f5_row4_col3" class="data row4 col3" >0.105</td>
#     </tr>
#     <tr>
#       <th id="T_872f5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_872f5_row5_col0" class="data row5 col0" >#0027</td>
#       <td id="T_872f5_row5_col1" class="data row5 col1" >0.117</td>
#       <td id="T_872f5_row5_col2" class="data row5 col2" >0.254</td>
#       <td id="T_872f5_row5_col3" class="data row5 col3" >0.119</td>
#     </tr>
#     <tr>
#       <th id="T_872f5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_872f5_row6_col0" class="data row6 col0" >#0030</td>
#       <td id="T_872f5_row6_col1" class="data row6 col1" >0.101</td>
#       <td id="T_872f5_row6_col2" class="data row6 col2" >0.194</td>
#       <td id="T_872f5_row6_col3" class="data row6 col3" >0.110</td>
#     </tr>
#     <tr>
#       <th id="T_872f5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_872f5_row7_col0" class="data row7 col0" >#0034</td>
#       <td id="T_872f5_row7_col1" class="data row7 col1" >0.128</td>
#       <td id="T_872f5_row7_col2" class="data row7 col2" >0.200</td>
#       <td id="T_872f5_row7_col3" class="data row7 col3" >0.118</td>
#     </tr>
#     <tr>
#       <th id="T_872f5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_872f5_row8_col0" class="data row8 col0" >#0037</td>
#       <td id="T_872f5_row8_col1" class="data row8 col1" >0.102</td>
#       <td id="T_872f5_row8_col2" class="data row8 col2" >0.185</td>
#       <td id="T_872f5_row8_col3" class="data row8 col3" >0.101</td>
#     </tr>
#     <tr>
#       <th id="T_872f5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_872f5_row9_col0" class="data row9 col0" >#0038</td>
#       <td id="T_872f5_row9_col1" class="data row9 col1" >0.110</td>
#       <td id="T_872f5_row9_col2" class="data row9 col2" >0.220</td>
#       <td id="T_872f5_row9_col3" class="data row9 col3" >0.122</td>
#     </tr>
#     <tr>
#       <th id="T_872f5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_872f5_row10_col0" class="data row10 col0" >#0039</td>
#       <td id="T_872f5_row10_col1" class="data row10 col1" >0.111</td>
#       <td id="T_872f5_row10_col2" class="data row10 col2" >0.271</td>
#       <td id="T_872f5_row10_col3" class="data row10 col3" >0.147</td>
#     </tr>
#     <tr>
#       <th id="T_872f5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_872f5_row11_col0" class="data row11 col0" >#0040</td>
#       <td id="T_872f5_row11_col1" class="data row11 col1" >0.108</td>
#       <td id="T_872f5_row11_col2" class="data row11 col2" >0.189</td>
#       <td id="T_872f5_row11_col3" class="data row11 col3" >0.108</td>
#     </tr>
#     <tr>
#       <th id="T_872f5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_872f5_row12_col0" class="data row12 col0" >#0041</td>
#       <td id="T_872f5_row12_col1" class="data row12 col1" >0.109</td>
#       <td id="T_872f5_row12_col2" class="data row12 col2" >0.235</td>
#       <td id="T_872f5_row12_col3" class="data row12 col3" >0.123</td>
#     </tr>
#     <tr>
#       <th id="T_872f5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_872f5_row13_col0" class="data row13 col0" >#0042</td>
#       <td id="T_872f5_row13_col1" class="data row13 col1" >0.104</td>
#       <td id="T_872f5_row13_col2" class="data row13 col2" >0.184</td>
#       <td id="T_872f5_row13_col3" class="data row13 col3" >0.115</td>
#     </tr>
#     <tr>
#       <th id="T_872f5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_872f5_row14_col0" class="data row14 col0" >#0043</td>
#       <td id="T_872f5_row14_col1" class="data row14 col1" >0.107</td>
#       <td id="T_872f5_row14_col2" class="data row14 col2" >0.188</td>
#       <td id="T_872f5_row14_col3" class="data row14 col3" >0.114</td>
#     </tr>
#     <tr>
#       <th id="T_872f5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_872f5_row15_col0" class="data row15 col0" >#0044</td>
#       <td id="T_872f5_row15_col1" class="data row15 col1" >0.111</td>
#       <td id="T_872f5_row15_col2" class="data row15 col2" >0.268</td>
#       <td id="T_872f5_row15_col3" class="data row15 col3" >0.116</td>
#     </tr>
#     <tr>
#       <th id="T_872f5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_872f5_row16_col0" class="data row1

# %% [markdown]
# Visualize the displacement field of one test-cell both as strain vector field and strain heat map.

# %%
get_ipython().run_line_magic('matplotlib', 'notebook')

fig, axs = plt.subplots(1,2, figsize=(9, 4))
fig.tight_layout(pad=3, w_pad=3, h_pad=3)
axs[0].quiver(X_test[5]['dspl'][:,:,0].T, X_test[5]['dspl'][:,:,1].T, scale=35)
axs[0].set_title('Displacement field: Strain vectors', {'fontsize': 11})
axs[0].plot(X_test[5]['brdx'][0], X_test[5]['brdy'][0])

C = np.sqrt(X_test[5]['dspl'][:,:,0].T ** 2 + X_test[5]['dspl'][:,:,1].T ** 2)
im = axs[1].pcolormesh(C, cmap='jet', shading='gouraud')
fig.colorbar(im, ax=axs[1])
axs[1].pcolormesh(C, cmap='jet', shading='gouraud')
axs[1].set_title('Displacement field: Strain heat map', {'fontsize': 11})
# Out:
# <img src="data:image/png;base64,..." width="900.0333333333333">
# Text(0.5, 1.0, 'Displacement field: Strain heat map')

# %%
# @@ Cell 325
predictions = {}
predictions['TracNet_SGD_Matlab'] = loadmat('/home/alexrichard/PycharmProjects/ml_in_biophysics/outputs/Tracnet_SGD_Matlab.mat')
predictions['TracNet_SGD_Python'] = np.moveaxis(predictTrac(torch.from_numpy(reshape(X_test[5]['dspl'][np.newaxis, :])), model_SGD, E=10670).detach().numpy()[0][0], [0,2], [2,0])
predictions['TracNet_ADAM_Python'] = np.moveaxis(predictTrac(torch.from_numpy(reshape(X_test[5]['dspl'][np.newaxis, :])), model_ADAM, E=10670).detach().numpy()[0][0], [0,2], [2,0])

# %%
get_ipython().run_line_magic('matplotlib', 'notebook')

fig, axs = plt.subplots(4, 2, figsize=(9, 13))
fig.tight_layout(pad=3, w_pad=3, h_pad=3)

axs[0, 0].quiver(y_test[5]['trac'][:,:,0].T, y_test[5]['trac'][:,:,1].T, scale=40000)
axs[0, 0].set_title('Ground truth: Stress vectors', {'fontsize': 11})
axs[0, 0].plot(y_test[5]['brdx'][0], y_test[5]['brdy'][0])

C = np.sqrt(y_test[5]['trac'][:,:,0].T ** 2 + y_test[5]['trac'][:,:,1].T ** 2)
im = axs[0,1].pcolormesh(C, cmap='jet', shading='gouraud')
fig.colorbar(im, ax=axs[0,1])
axs[0,1].pcolormesh(C, cmap='jet', shading='gouraud')
axs[0,1].set_title('Ground truth: Stress heat map', {'fontsize': 11})

axs[1, 0].quiver(predictions['TracNet_SGD_Matlab']['matlab_pred'][:,:,0].T, predictions['TracNet_SGD_Matlab']['matlab_pred'][:,:,1].T, scale=40000)
axs[1, 0].set_title('TracNet_SGD_Matlab: Stress vectors', {'fontsize': 11})

C = np.sqrt(predictions['TracNet_SGD_Matlab']['matlab_pred'][:,:,0].T ** 2 + predictions['TracNet_SGD_Matlab']['matlab_pred'][:,:,1].T ** 2)
im = axs[1,1].pcolormesh(C, cmap='jet', shading='gouraud')
fig.colorbar(im, ax=axs[1,1])
axs[1,1].pcolormesh(C, cmap='jet', shading='gouraud')
axs[1,1].set_title('TracNet_SGD_Matlab: Stress heat map', {'fontsize': 11})

axs[2, 0].quiver(predictions['TracNet_SGD_Python'][:,:,0].T, predictions['TracNet_SGD_Python'][:,:,1].T, scale=40000)
axs[2, 0].set_title('TracNet_SGD_Python: Stress vectors', {'fontsize': 11})

C = np.sqrt(predictions['TracNet_SGD_Python'][:,:,0].T ** 2 + predictions['TracNet_SGD_Python'][:,:,1].T ** 2)
im = axs[2,1].pcolormesh(C, cmap='jet', shading='gouraud')
fig.colorbar(im, ax=axs[2,1])
axs[2,1].pcolormesh(C, cmap='jet', shading='gouraud')
axs[2,1].set_title('TracNet_SGD_Python: Stress heat map', {'fontsize': 11})

axs[3, 0].quiver(predictions['TracNet_ADAM_Python'][:,:,0].T, predictions['TracNet_ADAM_Python'][:,:,1].T, scale=40000)
axs[3, 0].set_title('TracNet_ADAM_Python: Stress vectors', {'fontsize': 11})

C = np.sqrt(predictions['TracNet_ADAM_Python'][:,:,0].T ** 2 + predictions['TracNet_ADAM_Python'][:,:,1].T ** 2)
im = axs[3,1].pcolormesh(C, cmap='jet', shading='gouraud')
fig.colorbar(im, ax=axs[3,1])
axs[3,1].pcolormesh(C, cmap='jet', shading='gouraud')
axs[3,1].set_title('TracNet_ADAM_Python: Stress heat map', {'fontsize': 11})


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900.0333333333333">

# %% [markdown]
# ### 2. Experimental data from authors

# %% [markdown]
# Load data.

# %%
# Martinsried
experimental_dspl_path = '/home/alexrichard/LRZ Sync+Share/ML in Physics/Repos/DL-TFM-main/cells/cells/dspl'
experimental = matFiles_to_npArray(experimental_dspl_path) # each dict has keys ['brdx', 'brdy', 'dspl', 'name']

# %% [markdown]
# Plot strain field for one cell.

# %%
fig, axs = plt.subplots(1,2, figsize=(9, 4))
fig.tight_layout(pad=3, w_pad=3, h_pad=3)
axs[0].quiver(experimental[0]['dspl'][:,:,0].T, experimental[0]['dspl'][:,:,1].T, scale=35)
axs[0].set_title('NIH 3T3 cell displacement: Strain vectors', {'fontsize': 11})
axs[0].plot(experimental[0]['brdx'][0], experimental[0]['brdy'][0])

C = np.sqrt(experimental[0]['dspl'][:,:,0].T ** 2 +experimental[0]['dspl'][:,:,1].T ** 2)
im = axs[1].pcolormesh(C, cmap='jet', shading='gouraud')
fig.colorbar(im, ax=axs[1])
axs[1].pcolormesh(C, cmap='jet', shading='gouraud')
axs[1].set_title('NIH 3T3 cell displacement: Strain heat map', {'fontsize': 11})
# Out:
# <img src="data:image/png;base64,..." width="900.0333333333333">
# Text(0.5, 1.0, 'NIH 3T3 cell displacement: Strain heat map')

# %% [markdown]
# Calculate and plot predictions for this example. As this datapoint has been acquired experimentally, there is no ground truth available.

# %%
# @@ Cell 301
predictions = {}
predictions['TracNet_SGD_Matlab'] = loadmat('/home/alexrichard/PycharmProjects/ml_in_biophysics/outputs/Exp_pred.mat')
predictions['TracNet_SGD_Python'] = np.moveaxis(predictTrac(torch.from_numpy(reshape(experimental[0]['dspl'][np.newaxis, :])), model_SGD, E=10670).detach().numpy()[0][0], [0,2], [2,0])
predictions['TracNet_ADAM_Python'] = np.moveaxis(predictTrac(torch.from_numpy(reshape(experimental[0]['dspl'][np.newaxis, :])), model_ADAM, E=10670).detach().numpy()[0][0], [0,2], [2,0])
predictions['Easy-to-use_TFM'] = loadmat('/home/alexrichard/PycharmProjects/ml_in_biophysics/outputs/easy_trac_pred.mat')

# %%
get_ipython().run_line_magic('matplotlib', 'notebook')

fig, axs = plt.subplots(4, 2, figsize=(9, 13))
fig.tight_layout(pad=3, w_pad=3, h_pad=3)

axs[0, 0].quiver(predictions['TracNet_SGD_Matlab']['exp_trac'][:,:,0].T, predictions['TracNet_SGD_Matlab']['exp_trac'][:,:,1].T, scale=40000)
axs[0, 0].set_title('TracNet_SGD_Matlab: Stress vectors', {'fontsize': 11})

C = np.sqrt(predictions['TracNet_SGD_Matlab']['exp_trac'][:,:,0].T ** 2 + predictions['TracNet_SGD_Matlab']['exp_trac'][:,:,1].T ** 2)
im = axs[0,1].pcolormesh(C, cmap='jet', shading='gouraud')
fig.colorbar(im, ax=axs[0,1])
axs[0,1].pcolormesh(C, cmap='jet', shading='gouraud')
axs[0,1].set_title('TracNet_SGD_Matlab: Stress heat map', {'fontsize': 11})

axs[1, 0].quiver(predictions['TracNet_SGD_Python'][:,:,0].T, predictions['TracNet_SGD_Python'][:,:,1].T, scale=40000)
axs[1, 0].set_title('TracNet_SGD_Python: Stress vectors', {'fontsize': 11})

C = np.sqrt(predictions['TracNet_SGD_Python'][:,:,0].T ** 2 + predictions['TracNet_SGD_Python'][:,:,1].T ** 2)
im = axs[1,1].pcolormesh(C, cmap='jet', shading='gouraud')
fig.colorbar(im, ax=axs[1,1])
axs[1,1].pcolormesh(C, cmap='jet', shading='gouraud')
axs[1,1].set_title('TracNet_SGD_Python: Stress heat map', {'fontsize': 11})

axs[2, 0].quiver(predictions['TracNet_ADAM_Python'][:,:,0].T, predictions['TracNet_ADAM_Python'][:,:,1].T, scale=40000)
axs[2, 0].set_title('TracNet_ADAM_Python: Stress vectors', {'fontsize': 11})

C = np.sqrt(predictions['TracNet_ADAM_Python'][:,:,0].T ** 2 + predictions['TracNet_ADAM_Python'][:,:,1].T ** 2)
im = axs[2,1].pcolormesh(C, cmap='jet', shading='gouraud')
fig.colorbar(im, ax=axs[2,1])
axs[2,1].pcolormesh(C, cmap='jet', shading='gouraud')
axs[2,1].set_title('TracNet_ADAM_Python: Stress heat map', {'fontsize': 11})

axs[3, 0].quiver(predictions['Easy-to-use_TFM']['easy_trac_pred_'][:,:,0].T, predictions['Easy-to-use_TFM']['easy_trac_pred_'][:,:,1].T, scale=40000)
axs[3, 0].set_title('Easy-to-use-TFM package: Stress vectors', {'fontsize': 11})

C = np.sqrt(predictions['Easy-to-use_TFM']['easy_trac_pred_'][:,:,0].T ** 2 + predictions['Easy-to-use_TFM']['easy_trac_pred_'][:,:,1].T ** 2)
im = axs[3,1].pcolormesh(C, cmap='jet', shading='gouraud')
fig.colorbar(im, ax=axs[3,1])
axs[3,1].pcolormesh(C, cmap='jet', shading='gouraud')
axs[3,1].set_title('Easy-to-use-TFM package: Stress heat map', {'fontsize': 11})

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900.0333333333333">

# %% [markdown]
# ### 3. Artificial from Sabaß

# %% [markdown]
# Load already scaled data point containing three artificially created, circular traction spots.

# %%
# Martinsried
demo_dspl = loadmat('/home/alexrichard/PycharmProjects/ml_in_biophysics/outputs/demo_dspl.mat')['dspl']

# %%
get_ipython().run_line_magic('matplotlib', 'notebook')

fig, axs = plt.subplots(1,2, figsize=(9, 4))
fig.tight_layout(pad=3, w_pad=3, h_pad=3)
axs[0].quiver(demo_dspl[:,:,0], demo_dspl[:,:,1], scale=35)
axs[0].set_title('Demo dspl: Strain vectors', {'fontsize': 11})

C = np.sqrt(demo_dspl[:,:,0] ** 2 + demo_dspl[:,:,1] ** 2)
im = axs[1].pcolormesh(C, cmap='jet', shading='gouraud')
fig.colorbar(im, ax=axs[1])
axs[1].pcolormesh(C, cmap='jet', shading='gouraud')
axs[1].set_title('Demo dspl: Strain heat map', {'fontsize': 11})
# Out:
# <img src="data:image/png;base64,..." width="900.0333333333333">
# Text(0.5, 1.0, 'Demo dspl: Strain heat map')

# %%
# @@ Cell 332
distance_matrix = np.sqrt(demo_dspl[:,:,0] ** 2 + demo_dspl[:,:,1] ** 2)
i, j = np.unravel_index(distance_matrix.argmin(), distance_matrix.shape)
padded_demo_dspl = np.zeros(shape=(26,26,2))
padded_demo_dspl[:,:,0] = np.pad(demo_dspl[:,:,0], ((3, 2), (2, 3)), 'constant', constant_values=(demo_dspl[i][j][0], demo_dspl[i][j][0]))
padded_demo_dspl[:,:,1] = np.pad(demo_dspl[:,:,1], ((3, 2), (2, 3)), 'constant', constant_values=(demo_dspl[i][j][0], demo_dspl[i][j][0]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [78], in <module>
#       3 i, j = np.unravel_index(distance_matrix.argmin(), distance_matrix.shape)
#       4 padded_demo_dspl = np.zeros(shape=(26,26,2))
# ----> 5 padded_demo_dspl[:,:,0] = np.pad(demo_dspl[:,:,0], ((3, 2), (2, 3)), 'constant', constant_values=(demo_dspl[i][j][0], demo_dspl[i][j][0]))
#       6 padded_demo_dspl[:,:,1] = np.pad(demo_dspl[:,:,1], ((3, 2), (2, 3)), 'constant', constant_values=(demo_dspl[i][j][0], demo_dspl[i][j][0]))
#
# ValueError: could not broadcast input array from shape (109,109) into shape (26,26)

# %%
# @@ Cell 333
demo_dspl_dict = {}
demo_dspl_dict['dspl'] = demo_dspl
savemat("demo_dspl.mat", demo_dspl_dict)

# %%
predictions = {}
predictions['TracNet_SGD_Matlab'] = loadmat('/home/alexrichard/PycharmProjects/ml_in_biophysics/outputs/Demo_pred.mat')
predictions['TracNet_SGD_Python'] = np.moveaxis(predictTrac(torch.from_numpy(reshape(demo_dspl[np.newaxis, :])), model_SGD, E=10670).detach().numpy()[0][0], [0,2], [2,0])
predictions['TracNet_ADAM_Python'] = np.moveaxis(predictTrac(torch.from_numpy(reshape(demo_dspl[np.newaxis, :])), model_ADAM, E=10670).detach().numpy()[0][0], [0,2], [2,0])
predictions['Easy-to-use_TFM'] = loadmat('/home/alexrichard/PycharmProjects/ml_in_biophysics/outputs/easy_trac_pred.mat')

# %%
get_ipython().run_line_magic('matplotlib', 'notebook')

fig, axs = plt.subplots(4, 2, figsize=(9, 13))
fig.tight_layout(pad=3, w_pad=3, h_pad=3)

axs[0, 0].quiver(predictions['TracNet_SGD_Matlab']['demo_trac'][:,:,0], predictions['TracNet_SGD_Matlab']['demo_trac'][:,:,1], scale=40000)
axs[0, 0].set_title('TracNet_SGD_Matlab: Stress vectors', {'fontsize': 11})

C = np.sqrt(predictions['TracNet_SGD_Matlab']['demo_trac'][:,:,0] ** 2 + predictions['TracNet_SGD_Matlab']['demo_trac'][:,:,1] ** 2)
im = axs[0,1].pcolormesh(C, cmap='jet', shading='gouraud')
fig.colorbar(im, ax=axs[0,1])
axs[0,1].pcolormesh(C, cmap='jet', shading='gouraud')
axs[0,1].set_title('TracNet_SGD_Matlab: Stress heat map', {'fontsize': 11})

axs[1, 0].quiver(predictions['TracNet_SGD_Python'][:,:,0], predictions['TracNet_SGD_Python'][:,:,1], scale=40000)
axs[1, 0].set_title('TracNet_SGD_Python: Stress vectors', {'fontsize': 11})

C = np.sqrt(predictions['TracNet_SGD_Python'][:,:,0] ** 2 + predictions['TracNet_SGD_Python'][:,:,1] ** 2)
im = axs[1,1].pcolormesh(C, cmap='jet', shading='gouraud')
fig.colorbar(im, ax=axs[1,1])
axs[1,1].pcolormesh(C, cmap='jet', shading='gouraud')
axs[1,1].set_title('TracNet_SGD_Python: Stress heat map', {'fontsize': 11})

axs[2, 0].quiver(predictions['TracNet_ADAM_Python'][:,:,0], predictions['TracNet_ADAM_Python'][:,:,1], scale=40000)
axs[2, 0].set_title('TracNet_ADAM_Python: Stress vectors', {'fontsize': 11})

C = np.sqrt(predictions['TracNet_ADAM_Python'][:,:,0] ** 2 + predictions['TracNet_ADAM_Python'][:,:,1] ** 2)
im = axs[2,1].pcolormesh(C, cmap='jet', shading='gouraud')
fig.colorbar(im, ax=axs[2,1])
axs[2,1].pcolormesh(C, cmap='jet', shading='gouraud')
axs[2,1].set_title('TracNet_ADAM_Python: Stress heat map', {'fontsize': 11})

'''
axs[0, 0].quiver(y_test[5]['trac'][:,:,0].T, y_test[5]['trac'][:,:,1].T, scale=40000)
axs[0, 0].set_title('Ground truth: Stress vectors', {'fontsize': 11})
axs[0, 0].plot(y_test[5]['brdx'][0], y_test[5]['brdy'][0])

C = np.sqrt(y_test[5]['trac'][:,:,0].T ** 2 + y_test[5]['trac'][:,:,1].T ** 2)
im = axs[0,1].pcolormesh(C, cmap='jet', shading='gouraud')
fig.colorbar(im, ax=axs[0,1])
axs[0,1].pcolormesh(C, cmap='jet', shading='gouraud')
axs[0,1].set_title('Ground truth: Stress heat map', {'fontsize': 11})

'''

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="924.6">

# %% [markdown]
# ### 4 Experimental from Sabaß

# %%
# @@ Cell 301
predictions = {}
predictions['TracNet_SGD_Matlab'] = loadmat('/home/alexrichard/PycharmProjects/ml_in_biophysics/outputs/exp_trac.mat')
predictions['TracNet_SGD_Python'] = np.moveaxis(predictTrac(torch.from_numpy(reshape(experimental[0]['dspl'][np.newaxis, :])), model_SGD, E=10670).detach().numpy()[0][0], [0,2], [2,0])
predictions['TracNet_ADAM_Python'] = np.moveaxis(predictTrac(torch.from_numpy(reshape(experimental[0]['dspl'][np.newaxis, :])), model_ADAM, E=10670).detach().numpy()[0][0], [0,2], [2,0])
predictions['Easy-to-use_TFM'] = loadmat('/home/alexrichard/PycharmProjects/ml_in_biophysics/outputs/easy_trac_pred.mat')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/scipy/io/matlab/mio.py:39, in _open_file(file_like, appendmat, mode)
#      38 try:
# ---> 39     return open(file_like, mode), True
#      40 except IOError as e:
#      41     # Probably "not found"
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/alexrichard/PycharmProjects/ml_in_biophysics/outputs/exp_trac.mat'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Input In [46], in <module>
#       1 # @@ Cell 301
#       2 predictions = {}
# ----> 3 predictions['TracNet_SGD_Matlab'] = loadmat('/home/alexrichard/PycharmProjects/ml_in_biophysics/outputs/exp_trac.mat')
#       4 predictions['TracNet_SGD_Python'] = np.moveaxis(predictTrac(torch.from_numpy(reshape(experimental[0]['dspl'][np.newaxis, :])), model_SGD, E=10670).detach().numpy()[0][0], [0,2], [2,0])
#       5 predictions['TracNet_ADAM_Python'] = np.moveaxis(predictTrac(torch.from_numpy(reshape(experimental[0]['dspl'][np.newaxis, :])), model_ADAM, E=10670).detach().numpy()[0][0], [0,2], [2,0])
#
# File ~/.local/lib/python3.8/site-packages/scipy/io/matlab/mio.py:224, in loadmat(file_name, mdict, appendmat, **kwargs)
#      87 """
#      88 Load MATLAB file.
#      89
#    (...)
#     221     3.14159265+3.14159265j])
#     222 """
#     223 variable_names = kwargs.pop('variable_names', None)
# --> 224 with _open_file_context(file_name, appendmat) as f:
#     225     MR, _ = mat_reader_factory(f, **kwargs)
#     226     matfile_dict = MR.get_variables(variable_names)
#
# File /usr/lib/python3.8/contextlib.py:113, in _GeneratorContextManager.__enter__(self)
#     111 del self.args, self.kwds, self.func
#     112 try:
# --> 113     return next(self.gen)
#     114 except StopIteration:
#     115     raise RuntimeError("generator didn't yield") from None
#
# File ~/.local/lib/python3.8/site-packages/scipy/io/matlab/mio.py:17, in _open_file_context(file_like, appendmat, mode)
#      15 @contextmanager
#      16 def _open_file_context(file_like, appendmat, mode='rb'):
# ---> 17     f, opened = _open_file(file_like, appendmat, mode)
#      18     try:
#      19         yield f
#
# File ~/.local/lib/python3.8/site-packages/scipy/io/matlab/mio.py:45, in _open_file(file_like, appendmat, mode)
#      43     if appendmat and not file_like.endswith('.mat'):
#      44         file_like += '.mat'
# ---> 45     return open(file_like, mode), True
#      46 else:
#      47     raise IOError(
#      48         'Reader needs file name or open file-like object'
#      49     ) from e
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/alexrichard/PycharmProjects/ml_in_biophysics/outputs/exp_trac.mat'
